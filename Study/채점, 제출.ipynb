# %%
#점수 확인

score = round(module_name.score(X_train, Y_train) * 100, 2) #*100 : 백분률로 바꾸기(?) #2 : 소수점 아래 2자리까지 표시(?)
score

# %%
#제출
#pred로 예측값을 저장해논 상태
submission = pd.read_csv('file_direction')
submission['column'] = pred
submission.to_csv('sub.csv',index=False)
